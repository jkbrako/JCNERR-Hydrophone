# %% [markdown]
# <a href="https://colab.research.google.com/github/jkbrako/JCNERR-Hydrophone/blob/main/JCNERR_Passive_Acoustic_Hydrophone_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
clear
close all

% 2021_Apr_14_15

# %JB 7/27/2022 - Want to add a user input method for addpath and directory so user can
% search for files for graph appears

% JB 7/27/2022 - Could use fullfile

% addpath 'T:\RUMFS_Observatory\Acoustic_Observatory\2022_July_13_Download\'
% d = dir('T:\RUMFS_Observatory\Acoustic_Observatory\2022_July_13_Download\*.txt')

% fullFileName = user_input_test()
% d = dir(fullFileName)
% which -all user_input_test


%% set up sample matrix
nCols = 410;
formatstr = repmat('%f', [1 nCols]);
catformat = strcat('%*s%*f%*f%*f%*f',formatstr, '%*[^\n]');
hcatformat  = '%s%f%f%f%f%*[^\n]';

freq = [0	7.81	15.63	23.44	31.25	39.06	46.88	54.69	62.5   70.31	78.13	85.94	93.75	101.56	109.38	117.19	125	132.81	...
    140.63	148.44	156.25	164.06	171.88	179.69	187.5	195.31	203.13  210.94	218.75	226.56	234.38	242.19	250	257.81	265.63	273.44...
    281.25	289.06	296.88	304.69	312.5	320.31	328.13	335.94	343.75 351.56	359.38	367.19	375	382.81	390.63	398.44	406.25	414.06	421.88...
    429.69	437.5	445.31	453.13	460.94	468.75	476.56	484.38	492.19 500	507.81	515.63	523.44	531.25	539.06	546.88	554.69	562.5...
    570.31	578.13	585.94	593.75	601.56	609.38	617.19	625	632.81 640.63	648.44	656.25	664.06	671.88	679.69	687.5	695.31	703.13...
    710.94	718.75	726.56	734.38	742.19	750	757.81	765.63	773.44 781.25	789.06	796.88	804.69	812.5	820.31	828.13	835.94	843.75...
    851.56	859.38	867.19	875	882.81	890.63	898.44	906.25	914.06 921.88	929.69	937.5	945.31	953.13	960.94	968.75	976.56	984.38...
    992.19	1000	1007.81	1015.63	1023.44	1031.25	1039.06	1046.88	 1054.69	1062.5	1070.31	1078.13	1085.94	1093.75	1101.56	1109.38...
    1117.19	1125	1132.81	1140.63	1148.44	1156.25	1164.06	1171.88 1179.69	1187.5	1195.31	1203.13	1210.94	1218.75	1226.56	1234.38...
    1242.19	1250	1257.81	1265.63	1273.44	1281.25	1289.06	1296.88	1304.69 1312.5	1320.31	1328.13	1335.94	1343.75	1351.56	1359.38	1367.19	1375 ...
    1382.81	1390.63	1398.44	1406.25	1414.06	1421.88	1429.69	1437.5	1445.31 1453.13	1460.94	1468.75	1476.56	1484.38	1492.19	1500	1507.81	1515.63...
    1523.44	1531.25	1539.06	1546.88	1554.69	1562.5	1570.31	1578.13	1585.94 1593.75	1601.56	1609.38	1617.19	1625 ...
    1632.81	1640.63	1648.44	1656.25	1664.06	1671.88	1679.69	1687.5	1695.31 1703.13	1710.94	1718.75	1726.56	1734.38	1742.19	1750	1757.81	1765.63...
    1773.44	1781.25	1789.06	1796.88	1804.69	1812.5	1820.31	1828.13	1835.94 1843.75	1851.56	1859.38	1867.19	1875	1882.81	1890.63	1898.44	1906.25...
    1914.06	1921.88	1929.69	1937.5	1945.31	1953.13	1960.94	1968.75	1976.56 1984.38	1992.19	2000	2007.81	2015.63	2023.44	2031.25	2039.06	2046.88...
    2054.69	2062.5	2070.31	2078.13	2085.94	2093.75	2101.56	2109.38	2117.19 2125	2132.81	2140.63	2148.44	2156.25	2164.06	2171.88	2179.69	2187.5...
    2195.31	2203.13	2210.94	2218.75	2226.56	2234.38	2242.19	2250 2257.81	2265.63	2273.44	2281.25	2289.06	2296.88	2304.69	2312.5...
    2320.31	2328.13	2335.94	2343.75	2351.56	2359.38	2367.19	2375 2382.81	2390.63	2398.44	2406.25	2414.06	2421.88	2429.69	2437.5...
    2445.31	2453.13	2460.94	2468.75	2476.56	2484.38	2492.19	2500	2507.81 2515.63	2523.44	2531.25	2539.06	2546.88	2554.69	2562.5	2570.31	2578.13...
    2585.94	2593.75	2601.56	2609.38	2617.19	2625	2632.81	2640.63	2648.44 2656.25	2664.06	2671.88	2679.69	2687.5	2695.31	2703.13	2710.94	2718.75...
    2726.56	2734.38	2742.19	2750	2757.81	2765.63	2773.44	2781.25	2789.06	2796.88	2804.69	2812.5	2820.31	2828.13	2835.94	2843.75	2851.56	2859.38	2867.19...
    2875	2882.81	2890.63	2898.44	2906.25	2914.06	2921.88	2929.69	2937.5	2945.31	2953.13	2960.94	2968.75	2976.56	2984.38	2992.19	3000	3007.81...
    3015.63	3023.44	3031.25	3039.06	3046.88	3054.69	3062.5	3070.31	3078.13	3085.94	3093.75	3101.56	3109.38	3117.19	3125	3132.81	3140.63	3148.44...
    3156.25	3164.06	3171.88	3179.69	3187.5	3195.31];

% yticklabs = [freq(50), freq(100), freq(150), freq(200), freq(250), freq(300), freq(350), freq(400)];
% yticklabs = num2str(yticklabs)

# %yticklabs ={'382.81', '773.44', '1164.06', '1554.69', '1945.31', '2335.94', '2726.56', '3117.19'}; %For use with full spectrum plotting
yticklabs ={'148.44', '304.69', '460.94', '617.19', '773.44', '929.69', '1085.94', '1242.19', '1398.44', '1554.69', '1710.94', '1867.19'}; %For use with half spectrum plotting (1: 240)

# %JB 7/15/2022 - Converted Hz to kHz (not displayed
# %yticklabs ={'.14844', '.30469', '.46094', '.61719', '.77344', '.92969', '1.08594', '1.24219', '1.39844', '1.55469', '1.71094', '1.86719'}; %For use with half spectrum plotting (1: 240)in kHz
%% Chose file folder

# %yticklabs = fliplr(yticklabs);
startingFolder = pwd; % Full directory of files.
folder = uigetdir(startingFolder);
% Now get .txt files
filePattern = fullfile(folder, '*.txt');
files = dir(filePattern);

%% Process files
p = input('Enter the number of files that you want to process: ')
m = 1

% Continue
numfiles = numel(files);
splTimeSeries = []; %zeros(numfiles(:,1),4);
for n = m:numfiles   %1430   % For files 1-(to all files in folder) selected
    fname = fullfile(folder, files(n).name);
    fprintf('Now processing file %s...\n', fname);

    % Figure out how to fix dataread issues

    [sampdate, temperature,humidity,sequence, datapts]= textread(fname, hcatformat, 'headerlines', 30);

    [fid,message] = fopen(fname,'r');

    datestring = extractAfter(fname,'SCF6039_');
    datestring = extractBefore(datestring,'_');
    yr = str2double(datestring(1:4));
    mo = str2double(datestring(5:6));
    dy = str2double(datestring(7:8));

    C = textscan(fid, catformat,  'CollectOutput', 1, 'headerlines', 30);
    fclose(fid);

    CC = cell2mat(C);
    CC = CC';
    CCshort = CC(1:240, :); % JB 7/15/22 (Explain: For half spectrum subplotting
    figure
    # %image(CC)
    h = pcolor(CCshort);  %, 'shading', 'interp'
    set(h, 'EdgeColor', 'none')
    k = colorbar;
    set(gca, 'YtickLabels',yticklabs);
    shading(gca,'interp')
    ylabel('Frequency (Hz)')
    # %JB 7/13/2022 - Changed from 'xlabel('Seconds'
    xlabel('Time (s)')

    [~,~,~,hr,mi,se] = datevec(sampdate);
    jday = datenum(yr, mo, dy, hr, mi, se);
    splset = [jday,CC(30,:)', CC(60,:)', CC(240,:)'];
    splTimeSeries = [splTimeSeries; splset];

%     k.Label.String = 'Decibels (dB)';
%      JB 7/15/2022 - Added title (not displayed)
%     title(k, 'The Capture of Auditory and Sonar Data from RUMFS Salt Marsh Hydrophone')

    % JB 7/15/2022 - Added label for decibel range with font size
    ylabel(k,'Power (dB)')
    k.Label.FontSize = 12;

    % JB 7/27/2022 - Flickers through graphs for visuals
    pause(0.01)
    close

    n
    m+p

    if n == (m + p) - 1
        m = m+p;
    c = input('Continue? (Type "1" for YES & Type "2" for NO): ')

        if c == 1
            # %repeat function
        elseif c == 2
            # %end function
             x = ['All requested files processed. Stopped at file #', num2str(n), '.'];
            disp(x)
            break
        else %Meant to end script when invalid inputs are inserted (Does not work)
            y = ['Invlid input. Stopped at file #', num2str(n), '.'];
            break
        end
%         disp('All files in folder will now be processed.')
    end

%     c = input('Continue? (y/n)', 's')
%
%     if c == 'y'
%       %repeat function
%     else if c == 'n'
%         %end function
%     end
        disp('All files in folder have been processed.')

end

%      c = input('Continue? (y/n)', 's')
%
%     if c == 'y'
%
%     else if c == 'n'
%         end

% figure
% plot( splTimeSeries(:,1), splTimeSeries(:,2));
% hold on
% plot( splTimeSeries(:,1), splTimeSeries(:,3));
% plot( splTimeSeries(:,1), splTimeSeries(:,4));
% datetick('x')
